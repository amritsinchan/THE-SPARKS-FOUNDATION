# %% [markdown]
# <a href="https://colab.research.google.com/github/amritsinchan/THE-SPARKS-FOUNDATION/blob/main/Decision_Tree_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PROBLEM STATEMENT : For the given ‘Iris’ dataset, create the Decision Tree classifier and visualize it graphically. The purpose is if we feed any new data to this classifier, it would be able to predict the right class accordingly.
#
# BY- AMRITSINCHAN KAUR
#
# DATASET : https://drive.google.com/file/d/11Iq7YvbWZbt8VXjfm06brx66b10YiwK-/view?usp=sharing

# %%
#import all libraries required
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/amritsinchan/THE-SPARKS-FOUNDATION/main/Iris.csv'
df = pd.read_csv(url)

# %%
#checking dimension of dataset
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#checking dimension of dataset
df.shape
# Out:
# (150, 6)

# %%
# Importing libraries
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Species'] = le.fit_transform(df['Species'])
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %% [markdown]
# Preparing the data
#
# divide the data into "attributes" (inputs) and "labels" (outputs).

# %%
x = df.iloc[:,1:5].values
y = df.iloc[:,-1].values

# %%
#to plot pairwise relationship in a dataset
sns.pairplot(df,hue='Species')

# %% [markdown]
#  Defining the Decision Tree Algorithm

# %%
# Defining the decision tree algorithm
from sklearn import tree
dt = tree.DecisionTreeClassifier()

# %% [markdown]
# Next step is to split this data into training and test sets by using Scikit-Learn's built-in train_test_split() method:

# %%
# Preparing testing annd training data
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.25, random_state = 0)

# %%
dt.fit(x_train,y_train)
dt.score(x_train,y_train)
# Out:
# 1.0

# %%
# Importing libraries for ploting tree
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
# Visualize the graph
dtree=DecisionTreeClassifier()
dtree.fit(x,y)
plt.figure(figsize = (20,20))
plot_tree(dtree, rounded = True, filled=True)
plt.show()
